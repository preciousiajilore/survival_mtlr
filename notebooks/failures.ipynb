# %%
#Imports:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
df = pd.read_csv("/Users/preciousajilore/Documents/GitHub/torchmtlr/notebooks/failures.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
